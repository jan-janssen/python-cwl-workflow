# %% [markdown]
# # Command Line

# %%
import pickle

# %%
with open("one.pickle", "wb") as f:
    pickle.dump(1, f)

# %%
with open("two.pickle", "wb") as f:
    pickle.dump(2, f)

# %%
# !python -m wrapper --function="workflow.get_sum" --arg_x=one.pickle --arg_y=two.pickle

# %%
with open("result.pickle", "rb") as f:
    print(pickle.load(f))
# Out:
# 3

# %% [markdown]
# # Common Workflow Language

# %%
! cwltool workflow.cwl workflow.yml
# Out:
# /srv/conda/envs/notebook/bin/cwltool:11: DeprecationWarning: Nesting argument groups is deprecated.
#   sys.exit(run())
# INFO /srv/conda/envs/notebook/bin/cwltool 3.1.20250110105449
# INFO Resolved 'workflow.cwl' to 'file:///home/jovyan/workflow.cwl'
# INFO [job workflow.cwl] /tmp/afb__gvg$ python \
#     /tmp/wb87nhq3/stgcd43dd9e-6615-4761-8b3f-6ebf539017ab/wrapper.py \
#     --function=workflow.get_sum \
#     '--arg_x={"basename": "one.pickle", "class": "File", "dirname": "/tmp/afb__gvg", "location": "file:///home/jovyan/one.pickle", "nameext": ".pickle", "nameroot": "one", "path": "/tmp/afb__gvg/one.pickle", "size": 5}' \
#     '--arg_y={"basename": "two.pickle", "class": "File", "dirname": "/tmp/afb__gvg", "location": "file:///home/jovyan/two.pickle", "nameext": ".pickle", "nameroot": "two", "path": "/tmp/afb__gvg/two.pickle", "size": 5}' \
#     /tmp/wb87nhq3/stgcd43dd9e-6615-4761-8b3f-6ebf539017ab/wrapper.py
# Traceback (most recent call last):
#   File "/tmp/wb87nhq3/stgcd43dd9e-6615-4761-8b3f-6ebf539017ab/wrapper.py", line 32, in <module>
#     arg.split("=")[0][6:]: convert_argument(arg=arg.split("=")[-1])
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/wb87nhq3/stgcd43dd9e-6615-4761-8b3f-6ebf539017ab/wrapper.py", line 18, in convert_argument
#     with open(arg, 'rb') as f:
#          ^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: '{"basename": "one.pickle", "class": "File", "dirname": "/tmp/afb__gvg", "location": "file:///home/jovyan/one.pickle", "nameext": ".pickle", "nameroot": "one", "path": "/tmp/afb__gvg/one.pickle", "size": 5}'
# WARNING [job workflow.cwl] exited with status: 1
# ERROR [job workflow.cwl] Job error:
# ("Error collecting output for parameter 'result_file': workflow.cwl:35:7: Did not find output file with glob pattern: ['result.pickle'].", {})
# WARNING [job workflow.cwl] completed permanentFail
# {}WARNING Final process status is permanentFail
