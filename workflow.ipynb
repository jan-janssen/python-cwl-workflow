# %% [markdown]
# # Command Line

# %%
import pickle

# %%
with open("one.pickle", "wb") as f:
    pickle.dump(1, f)

# %%
with open("two.pickle", "wb") as f:
    pickle.dump(2, f)

# %%
# !python -m wrapper --function="workflow.get_prod_and_div" --arg_x=one.pickle --arg_y=two.pickle

# %%
# !python -m wrapper --function="workflow.get_sum" --arg_x=prod.pickle --arg_y=div.pickle

# %%
with open("result.pickle", "rb") as f:
    print(pickle.load(f))
# Out:
# 2.5

# %% [markdown]
# # Common Workflow Language

# %%
! cwltool workflow.cwl workflow.yml
# Out:
# /srv/conda/envs/notebook/bin/cwltool:11: DeprecationWarning: Nesting argument groups is deprecated.
#   sys.exit(run())
# INFO /srv/conda/envs/notebook/bin/cwltool 3.1.20250110105449
# INFO Resolved 'workflow.cwl' to 'file:///home/jovyan/workflow.cwl'
# INFO [workflow ] start
# INFO [workflow ] starting step get_prod_and_div
# INFO [step get_prod_and_div] start
# INFO [job get_prod_and_div] /tmp/0w5lvvnt$ python \
#     /tmp/42lxc8hl/stgafa63c83-6d96-4ad4-b493-af28a3ffb178/wrapper.py \
#     --function=workflow.get_prod_and_div \
#     --arg_x=/tmp/42lxc8hl/stg4d1429a8-c95e-4822-b8a6-1c7bc79fcd38/one.pickle \
#     --arg_y=/tmp/42lxc8hl/stge88ac680-21be-475a-bb88-c26183ebe579/two.pickle
# INFO [job get_prod_and_div] completed success
# INFO [step get_prod_and_div] completed success
# INFO [workflow ] starting step get_sum
# INFO [step get_sum] start
# INFO [job get_sum] /tmp/d9jedv8c$ python \
#     /tmp/bra2lz2h/stg71d9e81e-522c-4b61-b5fe-06b303d7dafb/wrapper.py \
#     --function=workflow.get_sum \
#     --arg_x=/tmp/bra2lz2h/stge3359f2a-d097-46d3-9470-9c27697eceeb/prod.pickle \
#     --arg_y=/tmp/bra2lz2h/stg508019b7-6240-4048-ab17-dc040f5a18ae/div.pickle
# INFO [job get_sum] completed success
# INFO [step get_sum] completed success
# INFO [workflow ] completed success
# {
#     "result_file": {
#         "location": "file:///home/jovyan/result.pickle",
#         "basename": "result.pickle",
#         "class": "File",
#         "checksum": "sha1$3dfd802cefb317cc7138af1e3a299f565c74ddec",
#         "size": 21,
#         "path": "/home/jovyan/result.pickle"
#     }
# }INFO Final process status is success

# %%
with open("result.pickle", "rb") as f:
    print(pickle.load(f))
# Out:
# 2.5
